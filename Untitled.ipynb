# %%
import kecam
# %matplotlib inline

import os
import tensorflow as tf
from pathlib import Path

# %% [markdown]
# - Img and model selection :

# %%
#mm = kecam.yolor.YOLOR_CSP()
#model = "yolor_csp"
model = "yolov7_tiny"
mm = kecam.yolov7.YOLOV7_Tiny()
imm_orig = kecam.test_images.cat()
img_name = "cat"
#imm_orig = kecam.test_images.dog_cat()
#img_name = "cat_dog"
# Out:
# >>>> Load pretrained from: C:\Users\maxime.carrere\.keras\models\yolov7_tiny_coco.h5

# %% [markdown]
# - get model prediction for image :

# %%
print(imm_orig.shape)
imm = mm.preprocess_input([imm_orig])
preds = mm(imm)

print(preds.shape)
preds = mm.decode_predictions(preds)
bboxs, lables, confidences = preds[0]
kecam.coco.show_image_with_bboxes(imm_orig, bboxs, lables, confidences)
# Out:
# (512, 512, 3)
# (1, 10647, 85)
# <Axes: >

# %%
from xplique_test import Explainer
Explainer.methods
# Out:
# {'ig': xplique.attributions.integrated_gradients.IntegratedGradients,
#  'saliency': xplique.attributions.saliency.Saliency,
#  'deconvnet': xplique.attributions.deconvnet.DeconvNet,
#  'gradient_input': xplique.attributions.gradient_input.GradientInput,
#  'guided_backprop': xplique.attributions.guided_backpropagation.GuidedBackprop,
#  'sobol': xplique.attributions.global_sensitivity_analysis.sobol_attribution_method.SobolAttributionMethod,
#  'smoothgrad': xplique.attributions.smoothgrad.SmoothGrad}

# %%
explainer = Explainer(mm)
params = {
    "batch_size":16
}
method = "saliency"
explanation = explainer.apply(method, preds, imm, params)

# %%
explainer.vizualise(exp_name=f"{model}_{img_name}", dest_folder="img")

# %%
explainer.score("mufidelity", explanation, imm, preds, {"batch_size":16, "nb_samples":50})
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 explainer.score("mufidelity", explanation, imm, preds, {"batch_size":16})
#
# File ~\PycharmProjects\keras_cv\xplique_test.py:54, in Explainer.score(self, method, explanation, img, preds, params)
#      52 wrapper = ModelWrapper(self.model, img.shape[1], explanation.shape[2], self.nb_classes)
#      53 metric = self.metrics[method](wrapper, np.array(img), wrapper.get_boxes(preds), **params)
# ---> 54 return metric(explanation)
#
# File c:\users\maxime.carrere\pycharmprojects\keras_cv\venv\lib\site-packages\xplique\metrics\base.py:117, in ExplanationMetric.__call__(self, explanations)
#     114 def __call__(self,
#     115              explanations: Union[tf.Tensor, np.array]) -> float:
#     116     """Evaluate alias"""
# --> 117     return self.evaluate(explanations)
#
# File c:\users\maxime.carrere\pycharmprojects\keras_cv\venv\lib\site-packages\xplique\metrics\fidelity.py:123, in MuFidelity.evaluate(self, explanations)
#     119 # measure the two terms that should be correlated
#     120 preds = base - batch_predictions(self.model, degraded_inputs,
#     121                                 label, self.batch_size)
# --> 123 attrs = tf.reduce_sum(phi * (1.0 - self.subset_masks), (1, 2, 3))
#     124 corr_score = spearmanr(preds, attrs)[0]
#     126 # sanity check: if the model predictions are the same, no variation
#
# File c:\users\maxime.carrere\pycharmprojects\keras_cv\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\users\maxime.carrere\pycharmprojects\keras_cv\venv\lib\site-packages\tensorflow\python\framework\ops.py:7262, in raise_from_not_ok_status(e, name)
#    7260 def raise_from_not_ok_status(e, name):
#    7261   e.message += (" name: " + name if name is not None else "")
# -> 7262   raise core._status_to_exception(e) from None
#
# ResourceExhaustedError: {{function_node __wrapped__Mul_device_/job:localhost/replica:0/task:0/device:CPU:0}} OOM when allocating tensor with shape[200,416,416,416] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu [Op:Mul]
